# %% [markdown]
# # Unit 3: Altering Hudi tables in the Hive Metastore
#
# In unit 2, we learned about the Hudi table types. In this module, we will- alter a Hudi table name and observe metadata changes.

# %% [markdown]
# ### Initialize Spark Session

# %%
spark = SparkSession.builder \
  .appName("Hudi-Learning-Unit-03-PySpark") \
  .master("yarn")\
  .enableHiveSupport()\
  .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.hudi.catalog.HoodieCatalog") \
  .config("spark.sql.extensions", "org.apache.spark.sql.hudi.HoodieSparkSessionExtension") \
  .getOrCreate()
# Out:
# 23/07/25 16:22:33 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://gaia-dpgce-cpu-623600433888-m.us-central1-a.c.apache-hudi-lab.internal:39149">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>yarn</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ### Declare & define variables

# %%
PROJECT_ID_OUTPUT=!gcloud config get-value core/project
PROJECT_ID=PROJECT_ID_OUTPUT[0]

# %%
PROJECT_NBR_OUTPUT=!gcloud projects describe $PROJECT_ID --format="value(projectNumber)"
PROJECT_NBR=PROJECT_NBR_OUTPUT[0]

# %%
print(f"Project ID is {PROJECT_ID}")
print(f"Project Number is {PROJECT_NBR}")
# Out:
# Project ID is apache-hudi-lab
# Project Number is 623600433888

# %%
PERSIST_TO_BUCKET = f"gs://gaia_data_bucket-{PROJECT_NBR}"
HUDI_COW_BASE_GCS_URI = f"{PERSIST_TO_BUCKET}/nyc-taxi-trips-hudi-cow"
DATABASE_NAME = "taxi_db"
COW_TABLE_NAME = "nyc_taxi_trips_hudi_cow"

# %% [markdown]
# ## 1. Alter the Hudi table name to include cow keyword
#
# In module 2, we created a CoW table. In this section, we will rename the table to include cow suffix.

# %% [markdown]
# ### 1.1. Review the database and table entry in the managed Hive Metastore

# %%
spark.sql("SHOW databases;").show()
# Out:
# ivysettings.xml file not found in HIVE_HOME or HIVE_CONF_DIR,/etc/hive/conf.dist/ivysettings.xml will be used
# +---------+
# |namespace|
# +---------+
# |  default|
# |  taxi_db|
# +---------+

# %%
spark.sql("SHOW tables IN taxi_db;").show(truncate=False)
# Out:
# [Stage 0:>                                                          (0 + 1) / 1]
# +---------+-----------------------+-----------+
# |namespace|tableName              |isTemporary|
# +---------+-----------------------+-----------+
# |taxi_db  |nyc_taxi_trips_hudi_mor|false      |
# +---------+-----------------------+-----------+

# %% [markdown]
# Now that we know the name of the original table in the Hive Metastore, lets take a quick peek at the Hoodie metadata properties file in Cloud Storage (where Hudi colocates the metadata with the data)

# %% [markdown]
# ### 1.2. Review the hoodie.properties file colocated with the Hudi dataset
#
# Study the properties fiel construct carefully and note the database and table name

# %%
print(HUDI_COW_BASE_GCS_URI)
# Out:
# gs://gaia_data_bucket-623600433888/nyc-taxi-trips-hudi-cow

# %%
! gsutil cat $HUDI_COW_BASE_GCS_URI/.hoodie/hoodie.properties
# Out:
# #Properties saved on 2023-07-25T03:46:19.627732Z
# #Tue Jul 25 03:46:19 UTC 2023
# hoodie.table.type=COPY_ON_WRITE
# hoodie.table.metadata.partitions=files
# hoodie.table.precombine.field=pickup_datetime
# hoodie.table.partition.fields=trip_year,trip_month,trip_day
# hoodie.archivelog.folder=archived
# hoodie.table.create.schema={"type"\:"record","name"\:"topLevelRecord","fields"\:[{"name"\:"_hoodie_commit_time","type"\:["string","null"]},{"name"\:"_hoodie_commit_seqno","type"\:["string","null"]},{"name"\:"_hoodie_record_key","type"\:["string","null"]},{"name"\:"_hoodie_partition_path","type"\:["string","null"]},{"name"\:"_hoodie_file_name","type"\:["string","null"]},{"name"\:"taxi_type","type"\:["string","null"]},{"name"\:"trip_hour","type"\:["int","null"]},{"name"\:"trip_minute","type"\:["int","null"]},{"name"\:"vendor_id","type"\:["string","null"]},{"name"\:"pickup_datetime","type"\:[{"type"\:"long","logicalType"\:"timestamp-micros"},"null"]},{"name"\:"dropoff_datetime","type"\:[{"type"\:"long","logicalType"\:"timestamp-micros"},"null"]},{"name"\:"store_and_forward","type"\:["string","null"]},{"name"\:"rate_code","type"\:["string","null"]},{"name"\:"pickup_location_id","type"\:["string","null"]},{"name"\:"dropoff_location_id","type"\:["string","null"]},{"name"\:"passenger_count","type"\:["long","null"]},{"name"\:"trip_distance","type"\:[{"type"\:"fixed","name"\:"fixed","namespace"\:"topLevelRecord.trip_distance","size"\:16,"logicalType"\:"decimal","precision"\:38,"scale"\:9},"null"]},{"name"\:"fare_amount","type"\:[{"type"\:"fixed","name"\:"fixed","namespace"\:"topLevelRecord.fare_amount","size"\:16,"logicalType"\:"decimal","precision"\:38,"scale"\:9},"null"]},{"name"\:"surcharge","type"\:[{"type"\:"fixed","name"\:"fixed","namespace"\:"topLevelRecord.surcharge","size"\:16,"logicalType"\:"decimal","precision"\:38,"scale"\:9},"null"]},{"name"\:"mta_tax","type"\:[{"type"\:"fixed","name"\:"fixed","namespace"\:"topLevelRecord.mta_tax","size"\:16,"logicalType"\:"decimal","precision"\:38,"scale"\:9},"null"]},{"name"\:"tip_amount","type"\:[{"type"\:"fixed","name"\:"fixed","namespace"\:"topLevelRecord.tip_amount","size"\:16,"logicalType"\:"decimal","precision"\:38,"scale"\:9},"null"]},{"name"\:"tolls_amount","type"\:[{"type"\:"fixed","name"\:"fixed","namespace"\:"topLevelRecord.tolls_amount","size"\:16,"logicalType"\:"decimal","precision"\:38,"scale"\:9},"null"]},{"name"\:"improvement_surcharge","type"\:[{"type"\:"fixed","name"\:"fixed","namespace"\:"topLevelRecord.improvement_surcharge","size"\:5,"logicalType"\:"decimal","precision"\:10,"scale"\:0},"null"]},{"name"\:"total_amount","type"\:[{"type"\:"fixed","name"\:"fixed","namespace"\:"topLevelRecord.total_amount","size"\:16,"logicalType"\:"decimal","precision"\:38,"scale"\:9},"null"]},{"name"\:"payment_type_code","type"\:["string","null"]},{"name"\:"congestion_surcharge","type"\:[{"type"\:"fixed","name"\:"fixed","namespace"\:"topLevelRecord.congestion_surcharge","size"\:5,"logicalType"\:"decimal","precision"\:10,"scale"\:0},"null"]},{"name"\:"trip_type","type"\:["string","null"]},{"name"\:"ehail_fee","type"\:[{"type"\:"fixed","name"\:"fixed","namespace"\:"topLevelRecord.ehail_fee","size"\:5,"logicalType"\:"decimal","precision"\:10,"scale"\:0},"null"]},{"name"\:"partition_date","type"\:[{"type"\:"int","logicalType"\:"date"},"null"]},{"name"\:"distance_between_service","type"\:[{"type"\:"fixed","name"\:"fixed","namespace"\:"topLevelRecord.distance_between_service","size"\:16,"logicalType"\:"decimal","precision"\:38,"scale"\:9},"null"]},{"name"\:"time_between_service","type"\:["long","null"]},{"name"\:"trip_year","type"\:["string","null"]},{"name"\:"trip_month","type"\:["string","null"]},{"name"\:"trip_day","type"\:["string","null"]}]}
# hoodie.timeline.layout.version=1
# hoodie.table.checksum=2893812949
# hoodie.datasource.write.drop.partition.columns=true
# hoodie.table.name=nyc_taxi_trips_hudi
# hoodie.table.recordkey.fields=taxi_type,trip_year,trip_month,trip_day,vendor_id,pickup_datetime,dropoff_datetime,pickup_location_id,dropoff_location_id
# hoodie.datasource.write.hive_style_partitioning=true
# hoodie.partition.metafile.use.base.format=true
# hoodie.table.keygenerator.class=org.apache.hudi.keygen.CustomKeyGenerator
# hoodie.populate.meta.fields=true
# hoodie.table.base.file.format=PARQUET
# hoodie.database.name=taxi_db
# hoodie.datasource.write.partitionpath.urlencode=false
# hoodie.table.version=5

# %% [markdown]
# ### 1.3. Rename the Hudi table taxi_db.nyc_taxi_trips_hudi to taxi_db.nyc_taxi_trips_hudi_cow

# %% [markdown]
# Lets run the table name update in the Hive Metastore; This should trigger metadata edits in Cloud Storage as well, in the Hudi metadata colocated with the Hudi dataset

# %%
spark.sql(f"ALTER table taxi_db.nyc_taxi_trips_hudi rename to taxi_db.{COW_TABLE_NAME};").show()
# Out:
# 23/07/25 16:24:59 WARN SessionState: METASTORE_FILTER_HOOK will be ignored, since hive.security.authorization.manager is set to instance of HiveAuthorizerFactory.
# ++
# ||
# ++
# ++

# %%
spark.sql("SHOW tables IN taxi_db;").show(truncate=False)
# Out:
# +---------+-----------------------+-----------+
# |namespace|tableName              |isTemporary|
# +---------+-----------------------+-----------+
# |taxi_db  |nyc_taxi_trips_hudi_cow|false      |
# |taxi_db  |nyc_taxi_trips_hudi_mor|false      |
# +---------+-----------------------+-----------+

# %% [markdown]
# Notice that the operations takes a couple minutes to complete despite just a rename operation - in the Hive Metastore, and in Cloud Storage. Lets review the metadata change in Cloud Storage - pay specific attention to the property: hoodie.table.name.

# %% [markdown]
# ### 1.4. Query the table & study the first five non-data columns
# Check if you can still query the table.
# Then study the Hudi specific metadata columns-
# _hoodie_commit_time - Timestamp column reflecting commit time
# _hoodie_commit_seqno - Commit sequence number
# _hoodie_record_key - Record key
# _hoodie_partition_path - Hive partition materialized scheme
# _hoodie_file_name - Hudi parquet file name
#
# Learn more about these columns from the Hudi documetation.

# %%
spark.sql(f"SELECT * FROM taxi_db.{COW_TABLE_NAME} WHERE trip_year=2022 AND trip_month=1 AND trip_day=31 LIMIT 1;").show(truncate=False)
# Out:
# 23/07/25 16:25:07 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# [Stage 17:=============================>                            (1 + 1) / 2]
# +-------------------+-----------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------+------------------------------------------------------------------------------+---------+---------+-----------+---------+-------------------+-------------------+-----------------+---------+------------------+-------------------+---------------+-------------+-----------+-----------+-----------+----------+------------+---------------------+------------+-----------------+--------------------+---------+---------+--------------+------------------------+--------------------+---------+----------+--------+
# |_hoodie_commit_time|_hoodie_commit_seqno   |_hoodie_record_key                                                                                                                                                                  |_hoodie_partition_path                 |_hoodie_file_name                                                             |taxi_type|trip_hour|trip_minute|vendor_id|pickup_datetime    |dropoff_datetime   |store_and_forward|rate_code|pickup_location_id|dropoff_location_id|passenger_count|trip_distance|fare_amount|surcharge  |mta_tax    |tip_amount|tolls_amount|improvement_surcharge|total_amount|payment_type_code|congestion_surcharge|trip_type|ehail_fee|partition_date|distance_between_service|time_between_service|trip_year|trip_month|trip_day|
# +-------------------+-----------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------+------------------------------------------------------------------------------+---------+---------+-----------+---------+-------------------+-------------------+-----------------+---------+------------------+-------------------+---------------+-------------+-----------+-----------+-----------+----------+------------+---------------------+------------+-----------------+--------------------+---------+---------+--------------+------------------------+--------------------+---------+----------+--------+
# |20230725033738727  |20230725033738727_304_0|taxi_type:yellow,trip_year:2022,trip_month:1,trip_day:31,vendor_id:2,pickup_datetime:1643655366000000,dropoff_datetime:1643655680000000,pickup_location_id:48,dropoff_location_id:68|trip_year=2022/trip_month=1/trip_day=31|f5a80079-b5ed-42dd-8439-8770fd67f5e7-0_304-127-15249_20230725033738727.parquet|yellow   |18       |56         |2        |2022-01-31 18:56:06|2022-01-31 19:01:20|N                |1.0      |48                |68                 |1              |1.150000000  |6.000000000|0.300000000|0.500000000|0E-9      |0E-9        |null                 |10.300000000|1                |null                |null     |null     |2022-01-31    |null                    |null                |2022     |1         |31      |
# +-------------------+-----------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------+------------------------------------------------------------------------------+---------+---------+-----------+---------+-------------------+-------------------+-----------------+---------+------------------+-------------------+---------------+-------------+-----------+-----------+-----------+----------+------------+---------------------+------------+-----------------+--------------------+---------+---------+--------------+------------------------+--------------------+---------+----------+--------+

# %% [markdown]
# ### 1.5. Review the hoodie.properties file to ensure it reflects the table name change

# %%
! gsutil cat "$HUDI_COW_BASE_GCS_URI/.hoodie/hoodie.properties"
# Out:
# #Properties saved on 2023-07-25T16:24:37.815856Z
# #Tue Jul 25 16:24:37 UTC 2023
# hoodie.table.type=COPY_ON_WRITE
# hoodie.table.metadata.partitions=files
# hoodie.table.precombine.field=pickup_datetime
# hoodie.table.partition.fields=trip_year,trip_month,trip_day
# hoodie.archivelog.folder=archived
# hoodie.table.create.schema={"type"\:"record","name"\:"topLevelRecord","fields"\:[{"name"\:"_hoodie_commit_time","type"\:["string","null"]},{"name"\:"_hoodie_commit_seqno","type"\:["string","null"]},{"name"\:"_hoodie_record_key","type"\:["string","null"]},{"name"\:"_hoodie_partition_path","type"\:["string","null"]},{"name"\:"_hoodie_file_name","type"\:["string","null"]},{"name"\:"taxi_type","type"\:["string","null"]},{"name"\:"trip_hour","type"\:["int","null"]},{"name"\:"trip_minute","type"\:["int","null"]},{"name"\:"vendor_id","type"\:["string","null"]},{"name"\:"pickup_datetime","type"\:[{"type"\:"long","logicalType"\:"timestamp-micros"},"null"]},{"name"\:"dropoff_datetime","type"\:[{"type"\:"long","logicalType"\:"timestamp-micros"},"null"]},{"name"\:"store_and_forward","type"\:["string","null"]},{"name"\:"rate_code","type"\:["string","null"]},{"name"\:"pickup_location_id","type"\:["string","null"]},{"name"\:"dropoff_location_id","type"\:["string","null"]},{"name"\:"passenger_count","type"\:["long","null"]},{"name"\:"trip_distance","type"\:[{"type"\:"fixed","name"\:"fixed","namespace"\:"topLevelRecord.trip_distance","size"\:16,"logicalType"\:"decimal","precision"\:38,"scale"\:9},"null"]},{"name"\:"fare_amount","type"\:[{"type"\:"fixed","name"\:"fixed","namespace"\:"topLevelRecord.fare_amount","size"\:16,"logicalType"\:"decimal","precision"\:38,"scale"\:9},"null"]},{"name"\:"surcharge","type"\:[{"type"\:"fixed","name"\:"fixed","namespace"\:"topLevelRecord.surcharge","size"\:16,"logicalType"\:"decimal","precision"\:38,"scale"\:9},"null"]},{"name"\:"mta_tax","type"\:[{"type"\:"fixed","name"\:"fixed","namespace"\:"topLevelRecord.mta_tax","size"\:16,"logicalType"\:"decimal","precision"\:38,"scale"\:9},"null"]},{"name"\:"tip_amount","type"\:[{"type"\:"fixed","name"\:"fixed","namespace"\:"topLevelRecord.tip_amount","size"\:16,"logicalType"\:"decimal","precision"\:38,"scale"\:9},"null"]},{"name"\:"tolls_amount","type"\:[{"type"\:"fixed","name"\:"fixed","namespace"\:"topLevelRecord.tolls_amount","size"\:16,"logicalType"\:"decimal","precision"\:38,"scale"\:9},"null"]},{"name"\:"improvement_surcharge","type"\:[{"type"\:"fixed","name"\:"fixed","namespace"\:"topLevelRecord.improvement_surcharge","size"\:5,"logicalType"\:"decimal","precision"\:10,"scale"\:0},"null"]},{"name"\:"total_amount","type"\:[{"type"\:"fixed","name"\:"fixed","namespace"\:"topLevelRecord.total_amount","size"\:16,"logicalType"\:"decimal","precision"\:38,"scale"\:9},"null"]},{"name"\:"payment_type_code","type"\:["string","null"]},{"name"\:"congestion_surcharge","type"\:[{"type"\:"fixed","name"\:"fixed","namespace"\:"topLevelRecord.congestion_surcharge","size"\:5,"logicalType"\:"decimal","precision"\:10,"scale"\:0},"null"]},{"name"\:"trip_type","type"\:["string","null"]},{"name"\:"ehail_fee","type"\:[{"type"\:"fixed","name"\:"fixed","namespace"\:"topLevelRecord.ehail_fee","size"\:5,"logicalType"\:"decimal","precision"\:10,"scale"\:0},"null"]},{"name"\:"partition_date","type"\:[{"type"\:"int","logicalType"\:"date"},"null"]},{"name"\:"distance_between_service","type"\:[{"type"\:"fixed","name"\:"fixed","namespace"\:"topLevelRecord.distance_between_service","size"\:16,"logicalType"\:"decimal","precision"\:38,"scale"\:9},"null"]},{"name"\:"time_between_service","type"\:["long","null"]},{"name"\:"trip_year","type"\:["string","null"]},{"name"\:"trip_month","type"\:["string","null"]},{"name"\:"trip_day","type"\:["string","null"]}]}
# hoodie.timeline.layout.version=1
# hoodie.table.checksum=2196815192
# hoodie.datasource.write.drop.partition.columns=true
# hoodie.table.name=nyc_taxi_trips_hudi_cow
# hoodie.table.recordkey.fields=taxi_type,trip_year,trip_month,trip_day,vendor_id,pickup_datetime,dropoff_datetime,pickup_location_id,dropoff_location_id
# hoodie.datasource.write.hive_style_partitioning=true
# hoodie.partition.metafile.use.base.format=true
# hoodie.table.keygenerator.class=org.apache.hudi.keygen.CustomKeyGenerator
# hoodie.populate.meta.fields=true
# hoodie.table.base.file.format=PARQUET
# hoodie.database.name=taxi_db
# hoodie.datasource.write.partitionpath.urlencode=false
# hoodie.table.version=5

# %% [markdown]
# This concludes the unit 4. Proceed to the next notebook.

# %%
# %%javascript
# Jupyter.notebook.session.delete();
